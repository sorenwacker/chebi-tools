# %%
from chebi_tools.interface import interface

# %%
interface.launch()
# Out:
# Running on local URL:  http://127.0.0.1:7861
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# WARNING:root:Multiple matches for "alanine":
#                        SOURCE  COMPOUND_ID     NAME        TYPE
# NAME_lowercase
# alanine         KEGG COMPOUND        16449  Alanine     SYNONYM
# alanine                 IUPAC        16449  alanine  IUPAC NAME
# alanine              PDBeChem        46217  ALANINE     SYNONYM
# alanine              PDBeChem        16977  ALANINE     SYNONYM
# alanine                 ChEBI        16449  alanine         NaN
# alanine                  JCBN        32439  alanine     SYNONYM
# Taking first entry.
# WARNING:root:Multiple matches for "alanine":
#                        SOURCE  COMPOUND_ID     NAME        TYPE
# NAME_lowercase
# ...
